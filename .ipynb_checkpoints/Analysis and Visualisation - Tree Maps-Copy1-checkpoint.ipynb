# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import squarify
import seaborn as sns
# %matplotlib inline

# %%
# Import map reduce poutput csv
df = pd.read_csv("CosmeticEC.csv", index_col=False)
df
# Out:
#        Unnamed: 0    user_id  Monetary  Frequency Recent_Date
# 0               0  562288986     39.61          8  2020-01-01
# 1               1  488417434     78.84         20  2020-02-17
# 2               2  515285785     20.99          5  2020-01-02
# 3               3  596274199     25.58          9  2020-01-03
# 4               4  129675214     41.17          9  2020-01-03
# ...           ...        ...       ...        ...         ...
# 49468       49468  615187883     11.11          2  2020-02-28
# 49469       49469  621877707      9.54          6  2020-02-29
# 49470       49470  621924311      0.16          1  2020-02-29
# 49471       49471  622041514      1.90          3  2020-02-29
# 49472       49472  621597689     17.30          2  2020-02-29
#
# [49473 rows x 5 columns]

# %%
# change the date format of recent date column
df["Recent_Date"] = pd.to_datetime(df["Recent_Date"],format = "%Y/%m/%d")

# %%
# Since we have 2 months of data, we choose 2 days after the end of February as a time stamp.The last
# purchase date made per user is subtracted from the time stamp to get the recency value.
import datetime as dt
study_date = dt.datetime(2020,3,2)
df["Recency"] = study_date - df["Recent_Date"]
df['Recency'].astype('timedelta64[D]')
df['Recency']=df['Recency'] / np.timedelta64(1, 'D')

# %%
df
# Out:
#        Unnamed: 0    user_id  Monetary  Frequency Recent_Date  Recency
# 0               0  562288986     39.61          8  2020-01-01     61.0
# 1               1  488417434     78.84         20  2020-02-17     14.0
# 2               2  515285785     20.99          5  2020-01-02     60.0
# 3               3  596274199     25.58          9  2020-01-03     59.0
# 4               4  129675214     41.17          9  2020-01-03     59.0
# ...           ...        ...       ...        ...         ...      ...
# 49468       49468  615187883     11.11          2  2020-02-28      3.0
# 49469       49469  621877707      9.54          6  2020-02-29      2.0
# 49470       49470  621924311      0.16          1  2020-02-29      2.0
# 49471       49471  622041514      1.90          3  2020-02-29      2.0
# 49472       49472  621597689     17.30          2  2020-02-29      2.0
#
# [49473 rows x 6 columns]

# %%
finaldf = df[["user_id","Monetary","Frequency","Recency"]]

# %%
finaldf
# Out:
#          user_id  Monetary  Frequency  Recency
# 0      562288986     39.61          8     61.0
# 1      488417434     78.84         20     14.0
# 2      515285785     20.99          5     60.0
# 3      596274199     25.58          9     59.0
# 4      129675214     41.17          9     59.0
# ...          ...       ...        ...      ...
# 49468  615187883     11.11          2      3.0
# 49469  621877707      9.54          6      2.0
# 49470  621924311      0.16          1      2.0
# 49471  622041514      1.90          3      2.0
# 49472  621597689     17.30          2      2.0
#
# [49473 rows x 4 columns]

# %%
# Create labels for Recency, Monetary and Frequency and assign quantiles
rec_labels = range(4,0,-1)
fr_labels = range(1, 5)
mon_labels = range(1, 5)
r_groups = pd.qcut(finaldf['Recency'], q=4, labels=rec_labels)
f_groups = pd.qcut(finaldf['Frequency'], q=4, labels=fr_labels)
m_groups = pd.qcut(finaldf['Monetary'], q=4, labels=mon_labels)

finaldf = finaldf.assign(R = r_groups.values, F = f_groups.values,M = m_groups.values)
finaldf.head()
# Out:
#      user_id  Monetary  Frequency  Recency  R  F  M
# 0  562288986     39.61          8     61.0  1  3  3
# 1  488417434     78.84         20     14.0  4  4  4
# 2  515285785     20.99          5     60.0  1  2  2
# 3  596274199     25.58          9     59.0  1  3  2
# 4  129675214     41.17          9     59.0  1  3  3

# %%
# determine rfm product score by multiplying the category labels
finaldf[["R", "F","M"]] = finaldf[["R", "F","M"]].apply(pd.to_numeric)
# Calculate RFM_Score
finaldf['RFM_Product'] = finaldf["R"]*finaldf["F"]*finaldf["M"]
print(finaldf['RFM_Product'].head())
# Out:
# 0     9
# 1    64
# 2     4
# 3     6
# 4     9
# Name: RFM_Product, dtype: int64

# %%
finaldf["RFM_Product"].describe()
# Out:
# count    49473.000000
# mean        18.047804
# std         17.842409
# min          1.000000
# 25%          4.000000
# 50%         12.000000
# 75%         27.000000
# max         64.000000
# Name: RFM_Product, dtype: float64

# %%
#Determine the rfm groups based on scaling
def rfmgroup(df):
    if df['RFM_Product'] >= 48:
        return 'Key Important Customers'
    elif ((df['RFM_Product'] >=36) and (df['RFM_Product'] < 48)):
        return 'Great Customers'
    elif ((df['RFM_Product'] >= 24) and (df['RFM_Product'] < 36)):
        return 'Loyal'
    elif ((df['RFM_Product'] >= 12) and (df['RFM_Product'] < 24)):
        return 'Good Potential'
    else:
        return 'Focus for Retention'

finaldf['RFM_Level'] = finaldf.apply(rfmgroup, axis=1)
finaldf.head()
# Out:
#      user_id  Monetary  Frequency  Recency  R  F  M  RFM_Product  \
# 0  562288986     39.61          8     61.0  1  3  3            9
# 1  488417434     78.84         20     14.0  4  4  4           64
# 2  515285785     20.99          5     60.0  1  2  2            4
# 3  596274199     25.58          9     59.0  1  3  2            6
# 4  129675214     41.17          9     59.0  1  3  3            9
#
#                  RFM_Level
# 0      Focus for Retention
# 1  Key Important Customers
# 2      Focus for Retention
# 3      Focus for Retention
# 4      Focus for Retention

# %%
# Calculate average values for each RFM_Level, and return a size of each segment 
rfm_level_agg = finaldf.groupby('RFM_Level').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': ['mean', 'count']
}).round(1)
# Print the aggregated dataset
print(rfm_level_agg)
# Out:
#                         Recency Frequency Monetary
#                            mean      mean     mean  count
# RFM_Level
# Focus for Retention        35.7       3.7     21.6  23589
# Good Potential             31.3       9.8     50.7  10298
# Great Customers            15.8      11.7     53.8   2567
# Key Important Customers    12.8      29.6    136.8   6596
# Loyal                      25.3      14.6     70.8   6423

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify

# rfm_level_agg.columns = rfm_level_agg.columns.droplevel()
# rfm_level_agg.columns = ['RecencyMean','FrequencyMean','MonetaryMean', 'Count']
#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 9)
squarify.plot(sizes=rfm_level_agg['Count'], 
              label=['Focus for Retention',
                     'Good Potential',
                     'Great Customers',
                     'Key Important Customers',
                     'Loyal'], alpha=.6 )
plt.title("RFM Segmentation",fontsize=25,fontweight="bold")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-252-e4b6f093b4ca> in <module>
#       7 ax = fig.add_subplot()
# ...

# %%
rfm.describe()
# Out:
#             user_id      Monetary     Frequency       Recency     RFM_Score
# count  4.947300e+04  49473.000000  49473.000000  49473.000000  49473.000000
# mean   5.407873e+08     51.095035     10.223556     29.371960      7.384614
# std    9.162650e+07     69.226884     14.346840     16.559573      2.244826
# min    1.028034e+07    -12.830000      1.000000      2.000000      3.000000
# 25%    5.045738e+08     16.110000      3.000000     15.000000      6.000000
# 50%    5.788074e+08     32.550000      6.000000     29.000000      7.000000
# 75%    6.047881e+08     57.930000     12.000000     43.000000      9.000000
# max    6.220732e+08   1850.400000    461.000000     61.000000     12.000000
